# %%
import pandas as pd
import os

# 1. menentukan jalur (path) ke folder datascraping
folder_path = 'datascraping'
file_name = 'master_dataset_aspirasi_dpr.csv'

# 2. menggabungkan folder dan nama file menjadi jalur lengkap
full_path = os.path.join(folder_path, file_name)

# 3. membaca data menggunakan pandas
df = pd.read_csv(full_path)

# 4. menampilkan informasi ringkas tentang data yang berhasil dimuat
print(f"Data berhasil dimuat dari: {full_path}")
print(f"Total baris data: {len(df)}")
print("-" * 30)
df.head()
# Out:
# Data berhasil dimuat dari: datascraping\master_dataset_aspirasi_dpr.csv
# Total baris data: 16379
# ------------------------------
#                   timestamp        username  \
# 0  2016-12-30T06:37:56.000Z   @majudepan578
# 1  2016-12-30T06:30:36.000Z             NaN
# 2  2016-12-30T04:48:35.000Z    @jiggerbunny
# 3  2016-12-30T04:21:40.000Z  @marunduri_tri
# 4  2016-12-30T02:36:13.000Z             NaN
#
#                                                 text  \
# 0  ADIL loh utk yg punya kebijakan publik & negar...
# 1  Tertibkan Media Online, DPR: Pemerintah Jangan...
# 2  @Portal_Kemlu_RI @DPR_RI @jokowi harus dievalu...
# 3  jangan ngambang, aturan logis apa undang-undan...
# 4  6. Kebebasan bersuara & berpendapat memang dij...
#
#                                        url_pencarian  tahun
# 0  https://x.com/search?q=(%22DPR%20RI%22%20OR%20...   2016
# 1  https://x.com/search?q=(%22DPR%20RI%22%20OR%20...   2016
# 2  https://x.com/search?q=(%22DPR%20RI%22%20OR%20...   2016
# ...
